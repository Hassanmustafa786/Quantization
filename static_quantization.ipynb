# %%
from functools import partial
from transformers import AutoTokenizer
from optimum.onnxruntime import ORTQuantizer, ORTModelForSequenceClassification
from optimum.onnxruntime.configuration import AutoQuantizationConfig, AutoCalibrationConfig
import warnings
warnings.filterwarnings("ignore")

model_id = "distilbert-base-uncased-finetuned-sst-2-english"

onnx_model = ORTModelForSequenceClassification.from_pretrained(model_id, export=True)
tokenizer = AutoTokenizer.from_pretrained(model_id)
quantizer = ORTQuantizer.from_pretrained(onnx_model)
qconfig = AutoQuantizationConfig.arm64(is_static=False, per_channel=True)
# Out:
# Framework not specified. Using pt to export the model.
# Using the export variant default. Available variants are:
#     - default: The default ONNX variant.
#
# ***** Exporting submodel 1/1: DistilBertForSequenceClassification *****
# Using framework PyTorch: 2.2.2

# %%
def preprocess_fn(ex, tokenizer):
    return tokenizer(ex["sentence"])

calibration_dataset = quantizer.get_calibration_dataset(
    "glue",
    dataset_config_name="sst2",
    preprocess_function=partial(preprocess_fn, tokenizer=tokenizer),
    num_samples=50,
    dataset_split="train",
)

calibration_config = AutoCalibrationConfig.minmax(calibration_dataset)

ranges = quantizer.fit(
    dataset=calibration_dataset,
    calibration_config=calibration_config,
    operators_to_quantize=qconfig.operators_to_quantize,
)
# Out:
# Using static quantization schema (dataset: parquet, method: CalibrationMethod.MinMax)
# Creating calibrator: CalibrationMethod.MinMax(CalibrationConfig(dataset_name='parquet', dataset_config_name='sst2', dataset_split='train', dataset_num_samples=50, method=<CalibrationMethod.MinMax: 0>, num_bins=None, num_quantized_bins=None, percentile=None, moving_average=False, averaging_constant=0.01))
# Collecting tensors statistics...
# Computing calibration ranges

# %%
model_quantized_path = quantizer.quantize(
    save_dir="Static Quantization/distilbert",
    calibration_tensors_range=ranges,
    quantization_config=qconfig,
)
# Out:
# Creating dynamic quantizer: QOperator (mode: IntegerOps, schema: u8/s8, channel-wise: True)
# Quantizing model...
# Saving quantized model at: Static Quantization/distilbert (external data format: False)
# Configuration saved in Static Quantization/distilbert/ort_config.json

# %%
import onnx

# Load the ONNX model
onnx_model = onnx.load("Static Quantization/distilbert/model_quantized.onnx")

# Iterate through the model's nodes
for node in onnx_model.graph.node:
    for input_tensor in node.input:
        input_info = next((i for i in onnx_model.graph.input if i.name == input_tensor), None)
        if input_info:
            data_type = input_info.type.tensor_type.elem_type
            print(f"Input tensor '{input_tensor}' of node '{node.name}' has data type: {onnx.mapping.TENSOR_TYPE_TO_NP_TYPE[data_type]}")

    for output_tensor in node.output:
        output_info = next((o for o in onnx_model.graph.output if o.name == output_tensor), None)
        if output_info:
            data_type = output_info.type.tensor_type.elem_type
            print(f"Output tensor '{output_tensor}' of node '{node.name}' has data type: {onnx.mapping.TENSOR_TYPE_TO_NP_TYPE[data_type]}")
# Out:
# Input tensor 'input_ids' of node '/distilbert/embeddings/word_embeddings/Gather' has data type: int64
# Input tensor 'attention_mask' of node '/distilbert/transformer/layer.0/attention/Equal' has data type: int64
# Output tensor 'logits' of node '/classifier/Gemm_Add' has data type: float32

# %%
import onnx

# Load the ONNX model
onnx_model = onnx.load("augmented_model.onnx")

# Iterate through the model's nodes
for node in onnx_model.graph.node:
    for input_tensor in node.input:
        input_info = next((i for i in onnx_model.graph.input if i.name == input_tensor), None)
        if input_info:
            data_type = input_info.type.tensor_type.elem_type
            print(f"Input tensor '{input_tensor}' of node '{node.name}' has data type: {onnx.mapping.TENSOR_TYPE_TO_NP_TYPE[data_type]}")

    for output_tensor in node.output:
        output_info = next((o for o in onnx_model.graph.output if o.name == output_tensor), None)
        if output_info:
            data_type = output_info.type.tensor_type.elem_type
            print(f"Output tensor '{output_tensor}' of node '{node.name}' has data type: {onnx.mapping.TENSOR_TYPE_TO_NP_TYPE[data_type]}")
# Out:
# Input tensor 'input_ids' of node '/distilbert/embeddings/word_embeddings/Gather' has data type: int64
# Input tensor 'attention_mask' of node '/distilbert/transformer/layer.0/attention/Equal' has data type: int64
# Output tensor 'logits' of node '/classifier/Gemm' has data type: float32
# Output tensor '/distilbert/transformer/layer.4/attention/Reshape_4_output_0_ReduceMin' of node '/distilbert/transformer/layer.4/attention/Reshape_4_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.4/attention/Reshape_4_output_0_ReduceMax' of node '/distilbert/transformer/layer.4/attention/Reshape_4_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.4/attention/Transpose_1_output_0_ReduceMin' of node '/distilbert/transformer/layer.4/attention/Transpose_1_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.4/attention/Transpose_1_output_0_ReduceMax' of node '/distilbert/transformer/layer.4/attention/Transpose_1_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.1/attention/q_lin/MatMul_output_0_ReduceMin' of node '/distilbert/transformer/layer.1/attention/q_lin/MatMul_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.1/attention/q_lin/MatMul_output_0_ReduceMax' of node '/distilbert/transformer/layer.1/attention/q_lin/MatMul_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.1/ffn/activation/Mul_1_output_0_ReduceMin' of node '/distilbert/transformer/layer.1/ffn/activation/Mul_1_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.1/ffn/activation/Mul_1_output_0_ReduceMax' of node '/distilbert/transformer/layer.1/ffn/activation/Mul_1_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.1/output_layer_norm/Add_1_output_0_ReduceMin' of node '/distilbert/transformer/layer.1/output_layer_norm/Add_1_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.1/output_layer_norm/Add_1_output_0_ReduceMax' of node '/distilbert/transformer/layer.1/output_layer_norm/Add_1_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.0/attention/Softmax_output_0_ReduceMin' of node '/distilbert/transformer/layer.0/attention/Softmax_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.0/attention/Softmax_output_0_ReduceMax' of node '/distilbert/transformer/layer.0/attention/Softmax_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.1/attention/Transpose_2_output_0_ReduceMin' of node '/distilbert/transformer/layer.1/attention/Transpose_2_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.1/attention/Transpose_2_output_0_ReduceMax' of node '/distilbert/transformer/layer.1/attention/Transpose_2_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.5/attention/Reshape_2_output_0_ReduceMin' of node '/distilbert/transformer/layer.5/attention/Reshape_2_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.5/attention/Reshape_2_output_0_ReduceMax' of node '/distilbert/transformer/layer.5/attention/Reshape_2_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.0/attention/v_lin/MatMul_output_0_ReduceMin' of node '/distilbert/transformer/layer.0/attention/v_lin/MatMul_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.0/attention/v_lin/MatMul_output_0_ReduceMax' of node '/distilbert/transformer/layer.0/attention/v_lin/MatMul_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.5/output_layer_norm/Add_1_output_0_ReduceMin' of node '/distilbert/transformer/layer.5/output_layer_norm/Add_1_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.5/output_layer_norm/Add_1_output_0_ReduceMax' of node '/distilbert/transformer/layer.5/output_layer_norm/Add_1_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.4/attention/q_lin/MatMul_output_0_ReduceMin' of node '/distilbert/transformer/layer.4/attention/q_lin/MatMul_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.4/attention/q_lin/MatMul_output_0_ReduceMax' of node '/distilbert/transformer/layer.4/attention/q_lin/MatMul_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.1/attention/Reshape_4_output_0_ReduceMin' of node '/distilbert/transformer/layer.1/attention/Reshape_4_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.1/attention/Reshape_4_output_0_ReduceMax' of node '/distilbert/transformer/layer.1/attention/Reshape_4_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.2/attention/q_lin/MatMul_output_0_ReduceMin' of node '/distilbert/transformer/layer.2/attention/q_lin/MatMul_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.2/attention/q_lin/MatMul_output_0_ReduceMax' of node '/distilbert/transformer/layer.2/attention/q_lin/MatMul_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.1/attention/out_lin/MatMul_output_0_ReduceMin' of node '/distilbert/transformer/layer.1/attention/out_lin/MatMul_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.1/attention/out_lin/MatMul_output_0_ReduceMax' of node '/distilbert/transformer/layer.1/attention/out_lin/MatMul_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.0/attention/Transpose_output_0_ReduceMin' of node '/distilbert/transformer/layer.0/attention/Transpose_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.0/attention/Transpose_output_0_ReduceMax' of node '/distilbert/transformer/layer.0/attention/Transpose_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.2/attention/MatMul_1_output_0_ReduceMin' of node '/distilbert/transformer/layer.2/attention/MatMul_1_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.2/attention/MatMul_1_output_0_ReduceMax' of node '/distilbert/transformer/layer.2/attention/MatMul_1_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.3/attention/Softmax_output_0_ReduceMin' of node '/distilbert/transformer/layer.3/attention/Softmax_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.3/attention/Softmax_output_0_ReduceMax' of node '/distilbert/transformer/layer.3/attention/Softmax_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.5/ffn/activation/Mul_1_output_0_ReduceMin' of node '/distilbert/transformer/layer.5/ffn/activation/Mul_1_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.5/ffn/activation/Mul_1_output_0_ReduceMax' of node '/distilbert/transformer/layer.5/ffn/activation/Mul_1_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.3/attention/Transpose_2_output_0_ReduceMin' of node '/distilbert/transformer/layer.3/attention/Transpose_2_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.3/attention/Transpose_2_output_0_ReduceMax' of node '/distilbert/transformer/layer.3/attention/Transpose_2_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.4/ffn/lin1/MatMul_output_0_ReduceMin' of node '/distilbert/transformer/layer.4/ffn/lin1/MatMul_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.4/ffn/lin1/MatMul_output_0_ReduceMax' of node '/distilbert/transformer/layer.4/ffn/lin1/MatMul_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.0/ffn/activation/Mul_1_output_0_ReduceMin' of node '/distilbert/transformer/layer.0/ffn/activation/Mul_1_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.0/ffn/activation/Mul_1_output_0_ReduceMax' of node '/distilbert/transformer/layer.0/ffn/activation/Mul_1_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.0/attention/MatMul_1_output_0_ReduceMin' of node '/distilbert/transformer/layer.0/attention/MatMul_1_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.0/attention/MatMul_1_output_0_ReduceMax' of node '/distilbert/transformer/layer.0/attention/MatMul_1_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.5/attention/Transpose_3_output_0_ReduceMin' of node '/distilbert/transformer/layer.5/attention/Transpose_3_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.5/attention/Transpose_3_output_0_ReduceMax' of node '/distilbert/transformer/layer.5/attention/Transpose_3_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.1/attention/Reshape_2_output_0_ReduceMin' of node '/distilbert/transformer/layer.1/attention/Reshape_2_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.1/attention/Reshape_2_output_0_ReduceMax' of node '/distilbert/transformer/layer.1/attention/Reshape_2_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.1/attention/v_lin/MatMul_output_0_ReduceMin' of node '/distilbert/transformer/layer.1/attention/v_lin/MatMul_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.1/attention/v_lin/MatMul_output_0_ReduceMax' of node '/distilbert/transformer/layer.1/attention/v_lin/MatMul_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.3/attention/Transpose_output_0_ReduceMin' of node '/distilbert/transformer/layer.3/attention/Transpose_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.3/attention/Transpose_output_0_ReduceMax' of node '/distilbert/transformer/layer.3/attention/Transpose_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.2/sa_layer_norm/Add_1_output_0_ReduceMin' of node '/distilbert/transformer/layer.2/sa_layer_norm/Add_1_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.2/sa_layer_norm/Add_1_output_0_ReduceMax' of node '/distilbert/transformer/layer.2/sa_layer_norm/Add_1_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.0/attention/Reshape_1_output_0_ReduceMin' of node '/distilbert/transformer/layer.0/attention/Reshape_1_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.0/attention/Reshape_1_output_0_ReduceMax' of node '/distilbert/transformer/layer.0/attention/Reshape_1_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.3/ffn/lin1/MatMul_output_0_ReduceMin' of node '/distilbert/transformer/layer.3/ffn/lin1/MatMul_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.3/ffn/lin1/MatMul_output_0_ReduceMax' of node '/distilbert/transformer/layer.3/ffn/lin1/MatMul_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.4/output_layer_norm/Add_1_output_0_ReduceMin' of node '/distilbert/transformer/layer.4/output_layer_norm/Add_1_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.4/output_layer_norm/Add_1_output_0_ReduceMax' of node '/distilbert/transformer/layer.4/output_layer_norm/Add_1_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.0/attention/MatMul_output_0_ReduceMin' of node '/distilbert/transformer/layer.0/attention/MatMul_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.0/attention/MatMul_output_0_ReduceMax' of node '/distilbert/transformer/layer.0/attention/MatMul_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.0/attention/Transpose_2_output_0_ReduceMin' of node '/distilbert/transformer/layer.0/attention/Transpose_2_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.0/attention/Transpose_2_output_0_ReduceMax' of node '/distilbert/transformer/layer.0/attention/Transpose_2_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.5/attention/Softmax_output_0_ReduceMin' of node '/distilbert/transformer/layer.5/attention/Softmax_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.5/attention/Softmax_output_0_ReduceMax' of node '/distilbert/transformer/layer.5/attention/Softmax_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.2/attention/Reshape_1_output_0_ReduceMin' of node '/distilbert/transformer/layer.2/attention/Reshape_1_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.2/attention/Reshape_1_output_0_ReduceMax' of node '/distilbert/transformer/layer.2/attention/Reshape_1_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.4/attention/MatMul_1_output_0_ReduceMin' of node '/distilbert/transformer/layer.4/attention/MatMul_1_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.4/attention/MatMul_1_output_0_ReduceMax' of node '/distilbert/transformer/layer.4/attention/MatMul_1_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.4/attention/Transpose_output_0_ReduceMin' of node '/distilbert/transformer/layer.4/attention/Transpose_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.4/attention/Transpose_output_0_ReduceMax' of node '/distilbert/transformer/layer.4/attention/Transpose_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.3/attention/Div_output_0_ReduceMin' of node '/distilbert/transformer/layer.3/attention/Div_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.3/attention/Div_output_0_ReduceMax' of node '/distilbert/transformer/layer.3/attention/Div_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.1/ffn/lin2/MatMul_output_0_ReduceMin' of node '/distilbert/transformer/layer.1/ffn/lin2/MatMul_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.1/ffn/lin2/MatMul_output_0_ReduceMax' of node '/distilbert/transformer/layer.1/ffn/lin2/MatMul_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '
layer_norm/Add_1_output_0_ReduceMax' of node '/distilbert/transformer/layer.3/sa_layer_norm/Add_1_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/embeddings/word_embeddings/Gather_output_0_ReduceMin' of node '/distilbert/embeddings/word_embeddings/Gather_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/embeddings/word_embeddings/Gather_output_0_ReduceMax' of node '/distilbert/embeddings/word_embeddings/Gather_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.3/attention/k_lin/MatMul_output_0_ReduceMin' of node '/distilbert/transformer/layer.3/attention/k_lin/MatMul_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.3/attention/k_lin/MatMul_output_0_ReduceMax' of node '/distilbert/transformer/layer.3/attention/k_lin/MatMul_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.0/ffn/lin1/MatMul_output_0_ReduceMin' of node '/distilbert/transformer/layer.0/ffn/lin1/MatMul_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.0/ffn/lin1/MatMul_output_0_ReduceMax' of node '/distilbert/transformer/layer.0/ffn/lin1/MatMul_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.5/attention/Reshape_1_output_0_ReduceMin' of node '/distilbert/transformer/layer.5/attention/Reshape_1_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.5/attention/Reshape_1_output_0_ReduceMax' of node '/distilbert/transformer/layer.5/attention/Reshape_1_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.2/attention/k_lin/MatMul_output_0_ReduceMin' of node '/distilbert/transformer/layer.2/attention/k_lin/MatMul_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.2/attention/k_lin/MatMul_output_0_ReduceMax' of node '/distilbert/transformer/layer.2/attention/k_lin/MatMul_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.1/attention/MatMul_1_output_0_ReduceMin' of node '/distilbert/transformer/layer.1/attention/MatMul_1_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.1/attention/MatMul_1_output_0_ReduceMax' of node '/distilbert/transformer/layer.1/attention/MatMul_1_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.5/attention/Reshape_4_output_0_ReduceMin' of node '/distilbert/transformer/layer.5/attention/Reshape_4_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.5/attention/Reshape_4_output_0_ReduceMax' of node '/distilbert/transformer/layer.5/attention/Reshape_4_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.3/attention/v_lin/MatMul_output_0_ReduceMin' of node '/distilbert/transformer/layer.3/attention/v_lin/MatMul_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.3/attention/v_lin/MatMul_output_0_ReduceMax' of node '/distilbert/transformer/layer.3/attention/v_lin/MatMul_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.5/sa_layer_norm/Add_1_output_0_ReduceMin' of node '/distilbert/transformer/layer.5/sa_layer_norm/Add_1_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.5/sa_layer_norm/Add_1_output_0_ReduceMax' of node '/distilbert/transformer/layer.5/sa_layer_norm/Add_1_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.0/attention/Transpose_3_output_0_ReduceMin' of node '/distilbert/transformer/layer.0/attention/Transpose_3_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.0/attention/Transpose_3_output_0_ReduceMax' of node '/distilbert/transformer/layer.0/attention/Transpose_3_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.3/attention/Reshape_2_output_0_ReduceMin' of node '/distilbert/transformer/layer.3/attention/Reshape_2_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.3/attention/Reshape_2_output_0_ReduceMax' of node '/distilbert/transformer/layer.3/attention/Reshape_2_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.0/attention/Div_output_0_ReduceMin' of node '/distilbert/transformer/layer.0/attention/Div_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.0/attention/Div_output_0_ReduceMax' of node '/distilbert/transformer/layer.0/attention/Div_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.0/attention/Transpose_1_output_0_ReduceMin' of node '/distilbert/transformer/layer.0/attention/Transpose_1_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.0/attention/Transpose_1_output_0_ReduceMax' of node '/distilbert/transformer/layer.0/attention/Transpose_1_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.0/attention/Reshape_4_output_0_ReduceMin' of node '/distilbert/transformer/layer.0/attention/Reshape_4_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.0/attention/Reshape_4_output_0_ReduceMax' of node '/distilbert/transformer/layer.0/attention/Reshape_4_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/embeddings/position_embeddings/Gather_output_0_ReduceMin' of node '/distilbert/embeddings/position_embeddings/Gather_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/embeddings/position_embeddings/Gather_output_0_ReduceMax' of node '/distilbert/embeddings/position_embeddings/Gather_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.2/attention/Transpose_1_output_0_ReduceMin' of node '/distilbert/transformer/layer.2/attention/Transpose_1_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.2/attention/Transpose_1_output_0_ReduceMax' of node '/distilbert/transformer/layer.2/attention/Transpose_1_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.3/ffn/lin2/MatMul_output_0_ReduceMin' of node '/distilbert/transformer/layer.3/ffn/lin2/MatMul_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.3/ffn/lin2/MatMul_output_0_ReduceMax' of node '/distilbert/transformer/layer.3/ffn/lin2/MatMul_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.5/attention/MatMul_output_0_ReduceMin' of node '/distilbert/transformer/layer.5/attention/MatMul_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.5/attention/MatMul_output_0_ReduceMax' of node '/distilbert/transformer/layer.5/attention/MatMul_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.2/attention/MatMul_output_0_ReduceMin' of node '/distilbert/transformer/layer.2/attention/MatMul_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.2/attention/MatMul_output_0_ReduceMax' of node '/distilbert/transformer/layer.2/attention/MatMul_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.5/attention/out_lin/MatMul_output_0_ReduceMin' of node '/distilbert/transformer/layer.5/attention/out_lin/MatMul_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.5/attention/out_lin/MatMul_output_0_ReduceMax' of node '/distilbert/transformer/layer.5/attention/out_lin/MatMul_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.3/attention/out_lin/MatMul_output_0_ReduceMin' of node '/distilbert/transformer/layer.3/attention/out_lin/MatMul_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.3/attention/out_lin/MatMul_output_0_ReduceMax' of node '/distilbert/transformer/layer.3/attention/out_lin/MatMul_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.1/attention/Reshape_output_0_ReduceMin' of node '/distilbert/transformer/layer.1/attention/Reshape_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.1/attention/Reshape_output_0_ReduceMax' of node '/distilbert/transformer/layer.1/attention/Reshape_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.4/attention/k_lin/MatMul_output_0_ReduceMin' of node '/distilbert/transformer/layer.4/attention/k_lin/MatMul_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.4/attention/k_lin/MatMul_output_0_ReduceMax' of node '/distilbert/transformer/layer.4/attention/k_lin/MatMul_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.3/attention/MatMul_output_0_ReduceMin' of node '/distilbert/transformer/layer.3/attention/MatMul_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.3/attention/MatMul_output_0_ReduceMax' of node '/distilbert/transformer/layer.3/attention/MatMul_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.4/attention/Reshape_2_output_0_ReduceMin' of node '/distilbert/transformer/layer.4/attention/Reshape_2_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.4/attention/Reshape_2_output_0_ReduceMax' of node '/distilbert/transformer/layer.4/attention/Reshape_2_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.1/attention/Softmax_output_0_ReduceMin' of node '/distilbert/transformer/layer.1/attention/Softmax_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.1/attention/Softmax_output_0_ReduceMax' of node '/distilbert/transformer/layer.1/attention/Softmax_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.3/attention/Transpose_3_output_0_ReduceMin' of node '/distilbert/transformer/layer.3/attention/Transpose_3_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.3/attention/Transpose_3_output_0_ReduceMax' of node '/distilbert/transformer/layer.3/attention/Transpose_3_output_0_ReduceMax_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.1/attention/Div_output_0_ReduceMin' of node '/distilbert/transformer/layer.1/attention/Div_output_0_ReduceMin_Reshape' has data type: float32
# Output tensor '/distilbert/transformer/layer.1/attention/Div_output_0_ReduceMax' of node '/distilbert/transformer/layer.1/attention/Div_output_0_ReduceMax_Reshape' has data type: float32

# %%
import os

# Check the size of the original ONNX model
original_model_size = os.path.getsize("augmented_model.onnx")
print(f"Original Model Size: {original_model_size / 1e6} MB")

# Check the size of the quantized ONNX model
quantized_model_size = os.path.getsize("Static Quantization/distilbert/model_quantized.onnx")
print(f"Quantized Model Size: {quantized_model_size / 1e6} MB")
# Out:
# Original Model Size: 268.157142 MB
# Quantized Model Size: 67.610578 MB
